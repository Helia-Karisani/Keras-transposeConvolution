# %%
import scipy
import matplotlib
import tensorflow as tf

print("scipy:", scipy.__version__)
print("matplotlib:", matplotlib.__version__)
print("tensorflow:", tf.__version__)
# Out:
# scipy: 1.14.1
# matplotlib: 3.9.3
# tensorflow: 2.18.0

# %% [markdown]
# I use numpy and matplotlib for data manipulation and visualization.

# %%
import warnings
warnings.simplefilter('ignore')

from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, UpSampling2D 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# define input layer

# %%
input_layer = Input(shape=(28, 28, 1))

# %% [markdown]
# adding transpose convolutional and convolutional layers

# %%
conv_layer = Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(input_layer) 

transpose_conv_layer = Conv2DTranspose(filters=1, kernel_size=(3, 3), activation='sigmoid', padding='same')(conv_layer)

# %% [markdown]
# creating the model

# %%
model = Model(inputs=input_layer, outputs=transpose_conv_layer)

# %% [markdown]
# compile the model

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# train the model<br>
#
# X_train will be the placeholder for the actual training data<br>
# y_train is the same as X_train for image reconstruction.

# %%
# generate synthetic training data 

X_train = np.random.rand(1000, 28, 28, 1) 

y_train = X_train # For reconstruction, the target is the input 

history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0753 - val_loss: 0.0645
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0523 - val_loss: 0.0394
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0296 - val_loss: 0.0206
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0151 - val_loss: 0.0107
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0083 - val_loss: 0.0063
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 0.0021

# %% [markdown]
# evaluate the model

# %%
 # generate synthetic test data 

X_test = np.random.rand(200, 28, 28, 1) 

y_test = X_test 

loss = model.evaluate(X_test, y_test) 

print(f'Test loss: {loss}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Test loss: 0.002043112413957715
